# %%
import numpy as np
from matplotlib import pyplot

# %%
np.random.randint(1,7,100)
# Out:
# array([5, 3, 3, 3, 2, 3, 3, 5, 3, 1, 3, 6, 6, 2, 4, 1, 3, 5, 1, 2, 6, 1,
#        1, 2, 4, 5, 2, 6, 1, 1, 1, 5, 4, 4, 5, 1, 5, 1, 6, 5, 1, 3, 1, 3,
#        2, 6, 2, 6, 1, 3, 6, 3, 2, 2, 1, 4, 1, 1, 2, 5, 4, 1, 6, 6, 6, 1,
#        6, 5, 2, 6, 6, 1, 2, 6, 6, 6, 1, 5, 4, 5, 4, 3, 6, 6, 6, 5, 5, 4,
#        3, 1, 6, 2, 3, 1, 4, 3, 2, 2, 4, 6])

# %%
m
# Out:
# [3.44,
#  3.4,
#  3.74,
#  3.04,
#  3.28,
#  3.43,
#  3.78,
#  3.49,
#  3.39,
#  3.22,
#  3.73,
#  3.95,
#  3.6,
#  3.28,
#  3.59,
#  3.61,
#  3.31,
#  3.76,
#  3.61,
#  3.48,
#  3.22,
#  3.44,
#  3.3,
#  3.64,
#  3.94,
#  3.35,
#  3.58,
#  3.72,
#  3.6,
#  3.32,
#  3.43,
#  3.6,
#  3.54,
#  3.28,
#  3.6,
#  3.59,
#  3.3,
#  3.74,
#  3.35,
#  3.72,
#  3.67,
#  3.35,
#  3.37,
#  3.49,
#  3.13,
#  3.77,
#  3.54,
#  3.33,
#  3.52,
#  3.45,
#  3.59,
#  3.51,
#  3.24,
#  3.64,
#  3.57,
#  3.6,
#  3.52,
#  3.2,
#  3.69,
#  3.39,
#  3.44,
#  3.86,
#  3.69,
#  3.32,
#  3.56,
#  3.59,
#  3.31,
#  3.38,
#  3.53,
#  3.43,
#  3.35,
#  3.42,
#  3.52,
#  3.55,
#  3.58,
#  3.58,
#  3.55,
#  3.45,
#  3.21,
#  3.76,
#  3.46,
#  3.53,
#  3.58,
#  3.37,
#  3.34,
#  3.3,
#  3.75,
#  3.75,
#  3.76,
#  3.45,
#  3.26,
#  3.58,
#  3.67,
#  3.45,
#  3.21,
#  3.36,
#  3.52,
#  3.58,
#  3.77,
#  3.07,
#  3.44,
#  3.63,
#  3.33,
#  3.65,
#  3.25,
#  3.31,
#  3.42,
#  3.61,
#  3.68,
#  3.41,
#  3.41,
#  3.61,
# ...

# %%
m = [np.mean(np.random.randint(1,7,100)) for _ in range(1000)]

# %%
pyplot.hist(m)
pyplot.show()
